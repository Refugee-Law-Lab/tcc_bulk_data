# %% [markdown]
# ### Notebook to load and analyze Tax Court of Canada cases
#
# Sean Rehaag
#
# License: Creative Commons Attribution-NonCommercial 4.0 International [(CC BY-NC 4.0)](https://creativecommons.org/licenses/by-nc/4.0/). NOTE: Users must also comply with upstream [licensing](https://www.tcc-cci.gc.ca/en/pages/important-notices) for the TCC source data, as well as requests on source urls not to allow indexing of the documents by search engines to protect privacy. As a result, users must not make the data available in formats or locations that can be indexed by search engines.
# `
# Dataset & Code to be cited as:
#
#     Sean Rehaag, "Tax Court of Canada Bulk Decisions Dataset" (2023), online: Refugee Law Laboratory <https://refugeelab.ca/bulk-data/tcc/>.
#
# Notes:
#
# (1) Data Source: [Tax Court of Canada](https://www.tcc-cci.gc.ca).
#
# (2) Unofficial Data: The data are unofficial reproductions of materials on the Tax Court of Canada website. Links to official versions are included in the dataset.
#
# (3) Non-Affiliation / Endorsement: The data has been collected and reproduced without any affiliation or endorsement from the Tax Court of Canada.
#
# (4) Non-Commerical Use: As indicated in the license, data may be used for non-commercial use (with attribution) only. For commercial use, see the Tax Court of Canada website's [Terms of Use](https://www.tcc-cci.gc.ca/en/pages/important-notices).
#
# (5) Accuracy: Data was collected and processed programmatically for the purposes of academic research. While we make best efforts to ensure accuracy, data gathering of this kind inevitably involves errors. As such the data should be viewed as preliminary information aimed to prompt further research and discussion, rather than as definitive information.
#
# (6) Limitation: Only includes cases with neutral citation, which began to be used in 2003
#
# (7) Delay: Decisions may take many months to be translated (sometimes over a year). As a result, in the most recent years, decisions may only be available in one language.
#
# ### Requirements:
#
#     pip install pandas
#
# ### If using parquet
#
#     pip install pyarrow
#
# ### if loading remotely (other than via Hugging Face)
#
#     pip install requests
#
# ### If loading remotely via Hugging Face
#
#     pip install datasets
#
#
# (Written on Python 3.9.12)
#
#
# (Written on Python 3.9.12)

# %% [markdown]
# ### Load Data
#
# Two Options: Local & Remote

# %%
# OPTION 1: Load Hugging Face dataset

from datasets import load_dataset
import pandas as pd

dataset = load_dataset("refugee-law-lab/canadian-legal-data", "TCC", split="train")

# convert to dataframe
df = pd.DataFrame(dataset)

df.head()
# Out:
# Downloading readme:   0%|          | 0.00/14.4k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/199M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
#        citation citation2 dataset  year                              name
# 0    2003 TCC 1               TCC  2003                Rodier c. La Reine  \
# 1  2003 TCC 100               TCC  2003                 Doering v. M.N.R.
# 2  2003 TCC 101               TCC  2003               Loewen v. The Queen
# 3  2003 TCC 102               TCC  2003                Dixon v. The Queen
# 4  2003 TCC 103               TCC  2003  S K Management Inc. v. The Queen
#
#   language document_date                                         source_url
# 0       en    2003-01-30  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...  \
# 1       en    2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 2       en    2003-03-14  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 3       en    2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 4       en    2003-03-07  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
#
#   scraped_timestamp                                    unofficial_text other
# 0        2022-09-02  Rodier c. La Reine\nCourt (s) Database\nTax Co...
# 1        2022-09-02  Doering v. M.N.R.\nCourt (s) Database\nTax Cou...
# 2        2022-09-02  Loewen v. The Queen\nCourt (s) Database\nTax C...
# 3        2022-09-02  Dixon v. The Queen\nCourt (s) Database\nTax Co...
# 4        2022-09-02  S K Management Inc. v. The Queen\nCourt (s) Da...

# %%
# OPTION 2: Load parquet data remotely from Huggingface without cloning repo
import pandas as pd
import requests
from io import BytesIO

url = 'https://huggingface.co/datasets/refugee-law-lab/canadian-legal-data/resolve/main/TCC/train.parquet'

# load data
results = requests.get(url)

# convert to dataframe
df = pd.read_parquet(BytesIO(results.content))
df.head()
# (if code fails, add engine='pyarrow' to read_parquet() function)
# Out:
#        citation citation2 dataset  year                              name
# 0    2003 TCC 1               TCC  2003                Rodier c. La Reine  \
# 1  2003 TCC 100               TCC  2003                 Doering v. M.N.R.
# 2  2003 TCC 101               TCC  2003               Loewen v. The Queen
# 3  2003 TCC 102               TCC  2003                Dixon v. The Queen
# 4  2003 TCC 103               TCC  2003  S K Management Inc. v. The Queen
#
#   language document_date                                         source_url
# 0       en    2003-01-30  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...  \
# 1       en    2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 2       en    2003-03-14  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 3       en    2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 4       en    2003-03-07  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
#
#   scraped_timestamp                                    unofficial_text other
# 0        2022-09-02  Rodier c. La Reine\nCourt (s) Database\nTax Co...
# 1        2022-09-02  Doering v. M.N.R.\nCourt (s) Database\nTax Cou...
# 2        2022-09-02  Loewen v. The Queen\nCourt (s) Database\nTax C...
# 3        2022-09-02  Dixon v. The Queen\nCourt (s) Database\nTax Co...
# 4        2022-09-02  S K Management Inc. v. The Queen\nCourt (s) Da...

# %%
# OPTION 3: Load json data remotely from GitHub without cloning repo

import pandas as pd
import json
import requests

# Set variables
start_year = 2003  # First year of data sought (2003 +)
end_year = 2024  # Last year of data sought (2024 -)


base_ulr = 'https://raw.githubusercontent.com/Refugee-Law-Lab/tcc_bulk_data/master/DATA/YEARLY/'

# load data
results = []
for year in range(start_year, end_year+1):
    url = base_ulr + f'{year}.json'
    results.extend(requests.get(url).json())

# convert to dataframe
df = pd.DataFrame(results)

df.head()
# Out:
#        citation citation2 dataset  year                              name
# 0    2003 TCC 1               TCC  2003                Rodier c. La Reine  \
# 1  2003 TCC 100               TCC  2003                 Doering v. M.N.R.
# 2  2003 TCC 101               TCC  2003               Loewen v. The Queen
# 3  2003 TCC 102               TCC  2003                Dixon v. The Queen
# 4  2003 TCC 103               TCC  2003  S K Management Inc. v. The Queen
#
#   language document_date                                         source_url
# 0       en    2003-01-30  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...  \
# 1       en    2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 2       en    2003-03-14  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 3       en    2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 4       en    2003-03-07  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
#
#   scraped_timestamp                                    unofficial_text other
# 0        2022-09-02  Rodier c. La Reine\nCourt (s) Database\nTax Co...
# 1        2022-09-02  Doering v. M.N.R.\nCourt (s) Database\nTax Cou...
# 2        2022-09-02  Loewen v. The Queen\nCourt (s) Database\nTax C...
# 3        2022-09-02  Dixon v. The Queen\nCourt (s) Database\nTax Co...
# 4        2022-09-02  S K Management Inc. v. The Queen\nCourt (s) Da...

# %%
# OPTION 4: Load json data locally via cloned repo

# First, clone git repo to local machine
# Then run this code to load data

import pandas as pd
import json
import pathlib

# Set variables
start_year = 2003  # First year of data sought (1877 +)
end_year = 2024  # Last year of data sought (2024 -)


# Set path to data
data_path = pathlib.Path('DATA/YEARLY/')

# load data (all years, json files)
results = []
for year in range(start_year, end_year+1):
    with open(data_path / f'{year}.json') as f:
        results.extend(json.load(f))

# convert to dataframe
df = pd.DataFrame(results)

df.head()
# Out:
#        citation citation2 dataset  year                              name
# 0    2003 TCC 1               TCC  2003                Rodier c. La Reine  \
# 1  2003 TCC 100               TCC  2003                 Doering v. M.N.R.
# 2  2003 TCC 101               TCC  2003               Loewen v. The Queen
# 3  2003 TCC 102               TCC  2003                Dixon v. The Queen
# 4  2003 TCC 103               TCC  2003  S K Management Inc. v. The Queen
#
#   language document_date                                         source_url
# 0       en    2003-01-30  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...  \
# 1       en    2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 2       en    2003-03-14  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 3       en    2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 4       en    2003-03-07  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
#
#   scraped_timestamp                                    unofficial_text other
# 0        2022-09-02  Rodier c. La Reine\nCourt (s) Database\nTax Co...
# 1        2022-09-02  Doering v. M.N.R.\nCourt (s) Database\nTax Cou...
# 2        2022-09-02  Loewen v. The Queen\nCourt (s) Database\nTax C...
# 3        2022-09-02  Dixon v. The Queen\nCourt (s) Database\nTax Co...
# 4        2022-09-02  S K Management Inc. v. The Queen\nCourt (s) Da...

# %% [markdown]
# ### Analyze Data

# %%
# View dataframe
df
# Out:
#            citation citation2 dataset  year
# 0        2003 TCC 1               TCC  2003  \
# 1      2003 TCC 100               TCC  2003
# 2      2003 TCC 101               TCC  2003
# 3      2003 TCC 102               TCC  2003
# 4      2003 TCC 103               TCC  2003
# ...             ...       ...     ...   ...
# 15292   2024 CCI 78               TCC  2024
# 15293   2024 CCI 79               TCC  2024
# 15294   2024 CCI 80               TCC  2024
# 15295   2024 CCI 85               TCC  2024
# 15296   2024 CCI 93               TCC  2024
#
#                                                     name language
# 0                                     Rodier c. La Reine       en  \
# 1                                      Doering v. M.N.R.       en
# 2                                    Loewen v. The Queen       en
# 3                                     Dixon v. The Queen       en
# 4                       S K Management Inc. v. The Queen       en
# ...                                                  ...      ...
# 15292  Entrepôt Frigorifique International Inc. c. Le...       fr
# 15293                SPE Valeur Assurable Inc. c. Le Roi       fr
# 15294                                    Tanga c. Le Roi       fr
# 15295                                  Ubartas c. M.R.N.       fr
# 15296                                  Barwicz c. Le Roi       fr
#
#       document_date                                         source_url
# 0        2003-01-30  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...  \
# 1        2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 2        2003-03-14  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 3        2003-03-12  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 4        2003-03-07  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# ...             ...                                                ...
# 15292    2024-05-27  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 15293    2024-05-27  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 15294    2024-05-31  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 15295    2024-06-10  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
# 15296    2024-07-08  https://decision.tcc-cci.gc.ca/tcc-cci/decisio...
#
#       scraped_timestamp                                    unofficial_text
# 0            2022-09-02  Rodier c. La Reine\nCourt (s) Database\nTax Co...  \
# 1            2022-09-02  Doering v. M.N.R.\nCourt (s) Database\nTax Cou...
# 2            2022-09-02  Loewen v. The Queen\nCourt (s) Database\nTax C...
# 3            2022-09-02  Dixon v. The Queen\nCourt (s) Database\nTax Co...
# 4            2022-09-02  S K Management Inc. v. The Queen\nCourt (s) Da...
# ...                 ...                                                ...
# 15292        2024-07-13  Entrepôt Frigorifique International Inc. c. Le...
# 15293        2024-07-13  SPE Valeur Assurable Inc. c. Le Roi\nBase de d...
# 15294        2024-07-13  Tanga c. Le Roi\nBase de données – Cour (s)\nJ...
# 15295        2024-07-13  Ubartas c. M.R.N.\nBase de données – Cour (s)\...
# 15296        2024-07-13  Barwicz c. Le Roi\nBase de données – Cour (s)\...
#
#       other
# 0
# 1
# 2
# 3
# 4
# ...     ...
# 15292
# 15293
# 15294
# 15295
# 15296
#
# [15297 rows x 11 columns]

# %%
# language counts
df['language'].value_counts()
# Out:
# language
# en    7744
# fr    7553
# Name: count, dtype: int64

# %%
# Yearly counts
year_counts = df.year.value_counts()
years_count = sorted(year_counts.index)
for year_count in years_count:
    print(f'{year_count}: {year_counts[year_count]}')
# Out:
# 2003: 1333
# 2004: 1371
# 2005: 1310
# 2006: 1112
# 2007: 1111
# 2008: 1135
# 2009: 1008
# 2010: 952
# 2011: 865
# 2012: 638
# 2013: 675
# 2014: 603
# 2015: 520
# 2016: 462
# 2017: 391
# 2018: 407
# 2019: 418
# 2020: 236
# 2021: 150
# 2022: 263
# 2023: 234
# 2024: 103
